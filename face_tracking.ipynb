# %% [markdown]
# # Face tracking pipeline
#
# The following example illustrates how to use the `facenet_pytorch` python package to perform face detection and tracking on an image dataset using MTCNN.

# %%
from facenet_pytorch import MTCNN
import torch
import numpy as np
#import mmcv
import cv2
from PIL import Image, ImageDraw
from IPython import display
import os,glob

# %% [markdown]
# #### Determine if an nvidia GPU is available

# %%
device = torch.device('cpu')
print('Running on device: {}'.format(device))
# Out:
# Running on device: cpu

# %% [markdown]
# #### Define MTCNN module
#
# Note that, since MTCNN is a collection of neural nets and other code, the device must be passed in the following way to enable copying of objects when needed internally.
#
# See `help(MTCNN)` for more details.

# %%
mtcnn = MTCNN(keep_all=True, device=device)

# %% [markdown]
# #### Get a sample video
#
# We begin by loading a video with some faces in it. The `mmcv` PyPI package by mmlabs is used to read the video frames (it can be installed with `pip install mmcv`). Frames are then converted to PIL images.

# %%
'''video = mmcv.VideoReader('video.mp4')
frames = [Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)) for frame in video]

display.Video('video.mp4', width=640)'''

#path = "/Users/rianbutala/Rian's projects/Coding/Facial Recognition/bse_face_recognition/img/train/notrian"
#save_path = "/Users/rianbutala/Rian's projects/Coding/Facial Recognition/bse_face_recognition/cropped/train/notrian"

path = "/Users/rianbutala/Rian's projects/Coding/Facial Recognition/bse_face_recognition/emotion_pictures/img/train/angry"
save_path = "/Users/rianbutala/Rian's projects/Coding/Facial Recognition/bse_face_recognition/emotion_pictures/cropped/train/angry"


os.chdir(path)

images = []
counter = 0

for file in glob.glob("*.jpeg"):
    with Image.open(file) as img:
        #img.show()
        images.append(file)
        print("parsed file count = " +str(counter))
        counter = counter + 1

for file in glob.glob("*.jpg"):
    with Image.open(file) as img:
        #img.show()
        images.append(file)
        print("parsed file count = " +str(counter))
        counter = counter + 1
for file in glob.glob("*.png"):
    with Image.open(file) as img:
        #img.show()
        images.append(file)
        print("parsed file count = " +str(counter))
        counter = counter + 1

print(type(images[0]))
# Out:
# parsed file count = 0
# parsed file count = 1
# parsed file count = 2
# parsed file count = 3
# parsed file count = 4
# parsed file count = 5
# parsed file count = 6
# parsed file count = 7
# parsed file count = 8
# parsed file count = 9
# parsed file count = 10
# parsed file count = 11
# parsed file count = 12
# parsed file count = 13
# parsed file count = 14
# parsed file count = 15
# parsed file count = 16
# parsed file count = 17
# parsed file count = 18
# parsed file count = 19
# parsed file count = 20
# parsed file count = 21
# parsed file count = 22
# parsed file count = 23
# parsed file count = 24
# parsed file count = 25
# parsed file count = 26
# parsed file count = 27
# parsed file count = 28
# parsed file count = 29
# parsed file count = 30
# parsed file count = 31
# parsed file count = 32
# parsed file count = 33
# parsed file count = 34
# parsed file count = 35
# parsed file count = 36
# parsed file count = 37
# parsed file count = 38
# parsed file count = 39
# parsed file count = 40
# parsed file count = 41
# parsed file count = 42
# parsed file count = 43
# parsed file count = 44
# parsed file count = 45
# parsed file count = 46
# parsed file count = 47
# parsed file count = 48
# parsed file count = 49
# parsed file count = 50
# parsed file count = 51
# parsed file count = 52
# parsed file count = 53
# parsed file count = 54
# parsed file count = 55
# parsed file count = 56
# parsed file count = 57
# parsed file count = 58
# parsed file count = 59
# parsed file count = 60
# parsed file count = 61
# parsed file count = 62
# parsed file count = 63
# parsed file count = 64
# parsed file count = 65
# parsed file count = 66
# parsed file count = 67
# parsed file count = 68
# parsed file count = 69
# parsed file count = 70
# parsed file count = 71
# parsed file count = 72
# parsed file count = 73
# parsed file count = 74
# parsed file count = 75
# parsed file count = 76
# parsed file count = 77
# parsed file count = 78
# parsed file count = 79
# parsed file count = 80
# parsed file count = 81
# parsed file count = 82
# parsed file count = 83
# parsed file count = 84
# parsed file count = 85
# parsed file count = 86
# parsed file count = 87
# parsed file count = 88
# parsed file count = 89
# parsed file count = 90
# parsed file count = 91
# parsed file count = 92
# parsed file count = 93
# parsed file count = 94
# parsed file count = 95
# parsed file count = 96
# parsed file count = 97
# parsed file count = 98
# parsed file count = 99
# parsed file count = 100
# parsed file count = 101
# parsed file count = 102
# parsed file count = 103
# parsed file count = 104
# parsed file count = 105
# parsed file count = 106
# parsed file count = 107
# parsed file count = 108
# parsed file count = 109
# parsed file count = 110
# parsed file count = 111
# parsed file count = 112
# parsed file count = 113
# parsed file count = 114
# parsed file count = 115
# parsed file count = 116
# parsed file count = 117
# parsed file count = 118
# parsed file count = 119
# parsed file count = 120
# parsed file count = 121
# parsed file count = 122
# parsed file count = 123
# parsed file count = 124
# parsed file count = 125
# parsed file count = 126
# parsed file count = 127
# parsed file count = 128
# parsed file count = 129
# parsed file count = 130
# parsed file count = 131
# parsed file count = 132
# parsed file count = 133
# parsed file count = 134
# parsed file count = 135
# parsed file count = 136
# parsed file count = 137
# parsed file count = 138
# parsed file count = 139
# parsed file count = 140
# parsed file count = 141
# parsed file count = 142
# parsed file count = 143
# parsed file count = 144
# parsed file count = 145
# parsed file count = 146
# parsed file count = 147
# parsed file count = 148
# parsed file count = 149
# parsed file count = 150
# parsed file count = 151
# parsed file count = 152
# parsed file count = 153
# parsed file count = 154
# parsed file count = 155
# parsed file count = 156
# parsed file count = 157
# parsed file count = 158
# parsed file count = 159
# parsed file count = 160
# parsed file count = 161
# parsed file count = 162
# parsed file count = 163
# parsed file count = 164
# parsed file count = 165
# parsed file count = 166
# parsed file count = 167
# parsed file count = 168
# parsed file count = 169
# parsed file count = 170
# parsed file count = 171
# parsed file count = 172
# parsed file count = 173
# parsed file count = 174
# parsed file count = 175
# parsed file count = 176
# parsed file count = 177
# parsed file count = 178
# parsed file count = 179
# parsed file count = 180
# parsed file count = 181
# parsed file count = 182
# parsed file count = 183
# parsed file count = 184
# parsed file count = 185
# parsed file count = 186
# parsed file count = 187
# parsed file count = 188
# parsed file count = 189
# parsed file count = 190
# parsed file count = 191
# parsed file count = 192
# parsed file count = 193
# parsed file count = 194
# parsed file count = 195
# parsed file count = 196
# parsed file count = 197
# parsed file count = 198
# parsed file count = 199
# parsed file count = 200
# parsed file count = 201
# parsed file count = 202
# parsed file count = 203
# parsed file count = 204
# parsed file count = 205
# parsed file count = 206
# parsed file count = 207
# parsed file count = 208
# parsed file count = 209
# parsed file count = 210
# parsed file count = 211
# parsed file count = 212
# parsed file count = 213
# parsed file count = 214
# parsed file count = 215
# parsed file count = 216
# parsed file count = 217
# parsed file count = 218
# parsed file count = 219
# parsed file count = 220
# parsed file count = 221
# parsed file count = 222
# parsed file count = 223
# parsed file count = 224
# parsed file count = 225
# parsed file count = 226
# parsed file count = 227
# parsed file count = 228
# parsed file count = 229
# parsed file count = 230
# parsed file count = 231
# parsed file count = 232
# parsed file count = 233
# parsed file count = 234
# parsed file count = 235
# parsed file count = 236
# parsed file count = 237
# parsed file count = 238
# parsed file count = 239
# parsed file count = 240
# parsed file count = 241
# parsed file count = 242
# parsed file count = 243
# parsed file count = 244
# parsed file count = 245
# parsed file count = 246
# parsed file count = 247
# parsed file count = 248
# parsed file count = 249
# parsed file count = 250
# parsed file count = 251
# parsed file count = 252
# parsed file count = 253
# parsed file count = 254
# parsed file count = 255
# parsed file count = 256
# parsed file count = 257
# parsed file count = 258
# parsed file count = 259
# parsed file count = 260
# parsed file count = 261
# parsed file count = 262
# parsed file count = 263
# parsed file count = 264
# parsed file count = 265
# parsed file count = 266
# parsed file count = 267
# parsed file count = 268
# parsed file count = 269
# parsed file count = 270
# parsed file count = 271
# parsed file count = 272
# parsed file count = 273
# parsed file count = 274
# parsed file count = 275
# parsed file count = 276
# parsed file count = 277
# parsed file count = 278
# parsed file count = 279
# parsed file count = 280
# parsed file count = 281
# parsed file count = 282
# parsed file count = 283
# parsed file count = 284
# parsed file count = 285
# parsed file count = 286
# parsed file count = 287
# parsed file count = 288
# parsed file count = 289
# parsed file count = 290
# parsed file count = 291
# parsed file count = 292
# parsed file count = 293
# parsed file count = 294
# parsed file count = 295
# parsed file count = 296
# parsed file count = 297
# parsed file count = 298
# parsed file count = 299
# parsed file count = 300
# parsed file count = 301
# parsed file count = 302
# parsed file count = 303
# parsed file count = 304
# parsed file count = 305
# parsed file count = 306
# parsed file count = 307
# parsed file count = 308
# parsed file count = 309
# parsed file count = 310
# parsed file count = 311
# parsed file count = 312
# parsed file count = 313
# parsed file count = 314
# parsed file count = 315
# parsed file count = 316
# parsed file count = 317
# parsed file count = 318
# parsed file count = 319
# parsed file count = 320
# parsed file count = 321
# parsed file count = 322
# parsed file count = 323
# parsed file count = 324
# parsed file count = 325
# parsed file count = 326
# parsed file count = 327
# parsed file count = 328
# parsed file count = 329
# parsed file count = 330
# parsed file count = 331
# parsed file count = 332
# parsed file count = 333
# parsed file count = 334
# parsed file count = 335
# parsed file count = 336
# parsed file count = 337
# parsed file count = 338
# parsed file count = 339
# parsed file count = 340
# parsed file count = 341
# parsed file count = 342
# parsed file count = 343
# parsed file count = 344
# parsed file count = 345
# parsed file count = 346
# parsed file count = 347
# parsed file count = 348
# parsed file count = 349
# parsed file count = 350
# parsed file count = 351
# parsed file count = 352
# parsed file count = 353
# parsed file count = 354
# parsed file count = 355
# parsed file count = 356
# parsed file count = 357
# parsed file count = 358
# parsed file count = 359
# parsed file count = 360
# parsed file count = 361
# parsed file count = 362
# parsed file count = 363
# parsed file count = 364
# parsed file count = 365
# parsed file count = 366
# parsed file count = 367
# parsed file count = 368
# parsed file count = 369
# parsed file count = 370
# parsed file count = 371
# parsed file count = 372
# parsed file count = 373
# parsed file count = 374
# parsed file count = 375
# parsed file count = 376
# parsed file count = 377
# parsed file count = 378
# parsed file count = 379
# parsed file count = 380
# parsed file count = 381
# parsed file count = 382
# parsed file count = 383
# parsed file count = 384
# parsed file count = 385
# parsed file count = 386
# parsed file count = 387
# parsed file count = 388
# parsed file count = 389
# parsed file count = 390
# parsed file count = 391
# parsed file count = 392
# parsed file count = 393
# parsed file count = 394
# parsed file count = 395
# parsed file count = 396
# parsed file count = 397
# parsed file count = 398
# parsed file count = 399
# parsed file count = 400
# parsed file count = 401
# parsed file count = 402
# parsed file count = 403
# parsed file count = 404
# parsed file count = 405
# parsed file count = 406
# parsed file count = 407
# parsed file count = 408
# parsed file count = 409
# parsed file count = 410
# parsed file count = 411
# parsed file count = 412
# parsed file count = 413
# parsed file count = 414
# parsed file count = 415
# parsed file count = 416
# parsed file count = 417
# parsed file count = 418
# parsed file count = 419
# parsed file count = 420
# parsed file count = 421
# parsed file count = 422
# parsed file count = 423
# parsed file count = 424
# parsed file count = 425
# parsed file count = 426
# parsed file count = 427
# parsed file count = 428
# parsed file count = 429
# parsed file count = 430
# parsed file count = 431
# parsed file count = 432
# parsed file count = 433
# parsed file count = 434
# parsed file count = 435
# parsed file count = 436
# parsed file count = 437
# parsed file count = 438
# parsed file count = 439
# parsed file count = 440
# parsed file count = 441
# parsed file count = 442
# parsed file count = 443
# parsed file count = 444
# parsed file count = 445
# parsed file count = 446
# parsed file count = 447
# parsed file count = 448
# parsed file count = 449
# parsed file count = 450
# parsed file count = 451
# parsed file count = 452
# parsed file count = 453
# parsed file count = 454
# parsed file count = 455
# parsed file count = 456
# parsed file count = 457
# parsed file count = 458
# parsed file count = 459
# parsed file count = 460
# parsed file count = 461
# parsed file count = 462
# parsed file count = 463
# parsed file count = 464
# parsed file count = 465
# parsed file count = 466
# parsed file count = 467
# parsed file count = 468
# parsed file count = 469
# parsed file count = 470
# parsed file count = 471
# parsed file count = 472
# parsed file count = 473
# parsed file count = 474
# parsed file count = 475
# parsed file count = 476
# parsed file count = 477
# parsed file count = 478
# parsed file count = 479
# parsed file count = 480
# parsed file count = 481
# parsed file count = 482
# parsed file count = 483
# parsed file count = 484
# parsed file count = 485
# parsed file count = 486
# parsed file count = 487
# parsed file count = 488
# parsed file count = 489
# parsed file count = 490
# parsed file count = 491
# parsed file count = 492
# parsed file count = 493
# parsed file count = 494
# parsed file count = 495
# parsed file count = 496
# parsed file count = 497
# parsed file count = 498
# parsed file count = 499
# parsed file count = 500
# parsed file count = 501
# parsed file count = 502
# parsed file count = 503
# parsed file count = 504
# parsed file count = 505
# parsed file count = 506
# parsed file count = 507
# parsed file count = 508
# parsed file count = 509
# parsed file count = 510
# parsed file count = 511
# parsed file count = 512
# parsed file count = 513
# parsed file count = 514
# parsed file count = 515
# parsed file count = 516
# parsed file count = 517
# parsed file count = 518
# parsed file count = 519
# parsed file count = 520
# parsed file count = 521
# parsed file count = 522
# parsed file count = 523
# parsed file count = 524
# parsed file count = 525
# parsed file count = 526
# parsed file count = 527
# parsed file count = 528
# parsed file count = 529
# parsed file count = 530
# parsed file count = 531
# parsed file count = 532
# parsed file count = 533
# parsed file count = 534
# parsed file count = 535
# parsed file count = 536
# parsed file count = 537
# parsed file count = 538
# parsed file count = 539
# parsed file count = 540
# parsed file count = 541
# parsed file count = 542
# parsed file count = 543
# parsed file count = 544
# parsed file count = 545
# parsed file count = 546
# parsed file count = 547
# parsed file count = 548
# parsed file count = 549
# parsed file count = 550
# parsed file count = 551
# parsed file count = 552
# parsed file count = 553
# parsed file count = 554
# parsed file count = 555
# parsed file count = 556
# parsed file count = 557
# parsed file count = 558
# parsed file count = 559
# parsed file count = 560
# parsed file count = 561
# parsed file count = 562
# parsed file count = 563
# parsed file count = 564
# parsed file count = 565
# parsed file count = 566
# parsed file count = 567
# parsed file count = 568
# parsed file count = 569
# parsed file count = 570
# parsed file count = 571
# parsed file count = 572
# parsed file count = 573
# parsed file count = 574
# parsed file count = 575
# parsed file count = 576
# parsed file count = 577
# parsed file count = 578
# parsed file count = 579
# parsed file count = 580
# parsed file count = 581
# parsed file count = 582
# parsed file count = 583
# parsed file count = 584
# parsed file count = 585
# parsed file count = 586
# parsed file count = 587
# parsed file count = 588
# parsed file count = 589
# parsed file count = 590
# parsed file count = 591
# parsed file count = 592
# parsed file count = 593
# parsed file count = 594
# parsed file count = 595
# parsed file count = 596
# parsed file count = 597
# parsed file count = 598
# parsed file count = 599
# parsed file count = 600
# parsed file count = 601
# parsed file count = 602
# parsed file count = 603
# parsed file count = 604
# parsed file count = 605
# parsed file count = 606
# parsed file count = 607
# parsed file count = 608
# parsed file count = 609
# parsed file count = 610
# parsed file count = 611
# parsed file count = 612
# parsed file count = 613
# parsed file count = 614
# parsed file count = 615
# parsed file count = 616
# parsed file count = 617
# parsed file count = 618
# parsed file count = 619
# parsed file count = 620
# parsed file count = 621
# parsed file count = 622
# parsed file count = 623
# parsed file count = 624
# parsed file count = 625
# parsed file count = 626
# parsed file count = 627
# parsed file count = 628
# parsed file count = 629
# parsed file count = 630
# parsed file count = 631
# parsed file count = 632
# parsed file count = 633
# parsed file count = 634
# parsed file count = 635
# parsed file count = 636
# parsed file count = 637
# parsed file count = 638
# parsed file count = 639
# parsed file count = 640
# parsed file count = 641
# parsed file count = 642
# parsed file count = 643
# parsed file count = 644
# parsed file count = 645
# parsed file count = 646
# parsed file count = 647
# parsed file count = 648
# parsed file count = 649
# parsed file count = 650
# parsed file count = 651
# parsed file count = 652
# parsed file count = 653
# parsed file count = 654
# parsed file count = 655
# parsed file count = 656
# parsed file count = 657
# parsed file count = 658
# parsed file count = 659
# parsed file count = 660
# parsed file count = 661
# parsed file count = 662
# parsed file count = 663
# parsed file count = 664
# parsed file count = 665
# parsed file count = 666
# parsed file count = 667
# parsed file count = 668
# parsed file count = 669
# parsed file count = 670
# parsed file count = 671
# parsed file count = 672
# parsed file count = 673
# parsed file count = 674
# parsed file count = 675
# parsed file count = 676
# parsed file count = 677
# parsed file count = 678
# parsed file count = 679
# parsed file count = 680
# parsed file count = 681
# parsed file count = 682
# parsed file count = 683
# parsed file count = 684
# parsed file count = 685
# parsed file count = 686
# parsed file count = 687
# parsed file count = 688
# parsed file count = 689
# parsed file count = 690
# parsed file count = 691
# parsed file count = 692
# parsed file count = 693
# parsed file count = 694
# parsed file count = 695
# parsed file count = 696
# parsed file count = 697
# parsed file count = 698
# parsed file count = 699
# parsed file count = 700
# parsed file count = 701
# parsed file count = 702
# parsed file count = 703
# parsed file count = 704
# parsed file count = 705
# parsed file count = 706
# parsed file count = 707
# parsed file count = 708
# parsed file count = 709
# parsed file count = 710
# parsed file count = 711
# parsed file count = 712
# parsed file count = 713
# parsed file count = 714
# parsed file count = 715
# parsed file count = 716
# parsed file count = 717
# parsed file count = 718
# parsed file count = 719
# parsed file count = 720
# parsed file count = 721
# parsed file count = 722
# parsed file count = 723
# parsed file count = 724
# parsed file count = 725
# parsed file count = 726
# parsed file count = 727
# parsed file count = 728
# parsed file count = 729
# parsed file count = 730
# parsed file count = 731
# parsed file count = 732
# parsed file count = 733
# parsed file count = 734
# parsed file count = 735
# parsed file count = 736
# parsed file count = 737
# parsed file count = 738
# parsed file count = 739
# parsed file count = 740
# parsed file count = 741
# parsed file count = 742
# parsed file count = 743
# parsed file count = 744
# parsed file count = 745
# parsed file count = 746
# parsed file count = 747
# parsed file count = 748
# parsed file count = 749
# parsed file count = 750
# parsed file count = 751
# parsed file count = 752
# parsed file count = 753
# parsed file count = 754
# parsed file count = 755
# parsed file count = 756
# parsed file count = 757
# parsed file count = 758
# parsed file count = 759
# parsed file count = 760
# parsed file count = 761
# parsed file count = 762
# parsed file count = 763
# parsed file count = 764
# parsed file count = 765
# parsed file count = 766
# parsed file count = 767
# parsed file count = 768
# parsed file count = 769
# parsed file count = 770
# parsed file count = 771
# parsed file count = 772
# parsed file count = 773
# parsed file count = 774
# parsed file count = 775
# parsed file count = 776
# parsed file count = 777
# parsed file count = 778
# parsed file count = 779
# parsed file count = 780
# parsed file count = 781
# parsed file count = 782
# parsed file count = 783
# parsed file count = 784
# parsed file count = 785
# parsed file count = 786
# parsed file count = 787
# parsed file count = 788
# parsed file count = 789
# parsed file count = 790
# parsed file count = 791
# parsed file count = 792
# parsed file count = 793
# parsed file count = 794
# parsed file count = 795
# parsed file count = 796
# parsed file count = 797
# parsed file count = 798
# parsed file count = 799
# parsed file count = 800
# parsed file count = 801
# parsed file count = 802
# parsed file count = 803
# parsed file count = 804
# parsed file count = 805
# parsed file count = 806
# parsed file count = 807
# parsed file count = 808
# parsed file count = 809
# parsed file count = 810
# parsed file count = 811
# parsed file count = 812
# parsed file count = 813
# parsed file count = 814
# parsed file count = 815
# parsed file count = 816
# parsed file count = 817
# parsed file count = 818
# parsed file count = 819
# parsed file count = 820
# parsed file count = 821
# parsed file count = 822
# parsed file count = 823
# parsed file count = 824
# parsed file count = 825
# parsed file count = 826
# parsed file count = 827
# parsed file count = 828
# parsed file count = 829
# parsed file count = 1127
# parsed file count = 1128
# parsed file count = 1129
# parsed file count = 1130
# parsed file count = 1131
# parsed file count = 1132
# parsed file count = 1133
# parsed file count = 1134
# parsed file count = 1135
# parsed file count = 1136
# parsed file count = 1137
# parsed file count = 1138
# parsed file count = 1139
# parsed file count = 1140
# parsed file count = 1141
# parsed file count = 1142
# parsed file count = 1143
# parsed file count = 1144
# parsed file count = 1145
# parsed file count = 1146
# parsed file count = 1147
# parsed file count = 1148
# parsed file count = 1149
# parsed file count = 1150
# parsed file count = 1151
# parsed file count = 1152
# parsed file count = 1153
# parsed file count = 1154
# parsed file count = 1155
# parsed file count = 1156
# parsed file count = 1157
# parsed file count = 1158
# parsed file count = 1159
# parsed file count = 1160
# parsed file count = 1161
# parsed file count = 1162
# parsed file count = 1163
# parsed file count = 1164
# parsed file count = 1165
# parsed file count = 1166
# parsed file count = 1167
# parsed file count = 1168
# parsed file count = 1169
# parsed file count = 1170
# parsed file count = 1171
# parsed file count = 1172
# parsed file count = 1173
# parsed file count = 1174
# parsed file count = 1175
# parsed file count = 1176
# parsed file count = 1177
# parsed file count = 1178
# parsed file count = 1179
# parsed file count = 1180
# parsed file count = 1181
# parsed file count = 1182
# parsed file count = 1183
# parsed file count = 1184
# parsed file count = 1185
# parsed file count = 1186
# parsed file count = 1187
# parsed file count = 1188
# parsed file count = 1189
# parsed file count = 1190
# parsed file count = 1191
# parsed file count = 1192
# parsed file count = 1193
# parsed file count = 1194
# parsed file count = 1195
# parsed file count = 1196
# parsed file count = 1197
# parsed file count = 1198
# parsed file count = 1199
# parsed file count = 1200
# parsed file count = 1201
# parsed file count = 1202
# parsed file count = 1203
# parsed file count = 1204
# parsed file count = 1205
# parsed file count = 1206
# parsed file count = 1207
# parsed file count = 1208
# parsed file count = 1209
# parsed file count = 1210
# parsed file count = 1211
# parsed file count = 1212
# parsed file count = 1213
# parsed file count = 1214
# parsed file count = 1215
# parsed file count = 1216
# parsed file count = 1217
# parsed file count = 1218
# parsed file count = 1219
# parsed file count = 1220
# parsed file count = 1221
# parsed file count = 1222
# parsed file count = 1223
# parsed file count = 1224
# parsed file count = 1225
# parsed file count = 1226
# parsed file count = 1227
# parsed file count = 1228
# parsed file count = 1229
# parsed file count = 1230
# parsed file count = 1231
# parsed file count = 1232
# parsed file count = 1233
# parsed file count = 1234
# parsed file count = 1235
# parsed file count = 1236
# parsed file count = 1237
# parsed file count = 1238
# parsed file count = 1239
# parsed file count = 1240
# parsed file count = 1241
# parsed file count = 1242
# parsed file count = 1243
# parsed file count = 1244
# parsed file count = 1245
# parsed file count = 1246
# parsed file count = 1247
# parsed file count = 1248
# parsed file count = 1249
# parsed file count = 1250
# parsed file count = 1251
# parsed file count = 1252
# parsed file count = 1253
# parsed file count = 1254
# parsed file count = 1255
# parsed file count = 1256
# parsed file count = 1257
# parsed file count = 1258
# parsed file count = 1259
# parsed file count = 1260
# parsed file count = 1261
# parsed file count = 1262
# parsed file count = 1263
# parsed file count = 1264
# parsed file count = 1265
# parsed file count = 1266
# parsed file count = 3920
# parsed file count = 3921
# parsed file count = 3922
# parsed file count = 3923
# parsed file count = 3924
# parsed file count = 3925
# parsed file count = 3926
# parsed file count = 3927
# parsed file count = 3928
# parsed file count = 3929
# parsed file count = 3930
# parsed file count = 3931
# parsed file count = 3932
# parsed file count = 3933
# parsed file count = 3934
# parsed file count = 3935
# parsed file count = 3936
# parsed file count = 3937
# parsed file count = 3938
# parsed file count = 3939
# parsed file count = 3940
# parsed file count = 3941
# parsed file count = 3942
# parsed file count = 3943
# parsed file count = 3944
# parsed file count = 3945
# parsed file count = 3946
# parsed file count = 3947
# parsed file count = 3948
# parsed file count = 3949
# parsed file count = 3950
# parsed file count = 3951
# parsed file count = 3952
# parsed file count = 3953
# parsed file count = 3954
# parsed file count = 3955
# parsed file count = 3956
# parsed file count = 3957
# parsed file count = 3958
# parsed file count = 3959
# parsed file count = 3960
# parsed file count = 3961
# parsed file count = 3962
# parsed file count = 3963
# parsed file count = 3964
# parsed file count = 3965
# parsed file count = 3966
# parsed file count = 3967
# parsed file count = 3968
# parsed file count = 3969
# parsed file count = 3970
# parsed file count = 3971
# parsed file count = 3972
# parsed file count = 3973
# parsed file count = 3974
# parsed file count = 3975
# parsed file count = 3976
# parsed file count = 3977
# parsed file count = 3978
# parsed file count = 3979
# parsed file count = 3980
# parsed file count = 3981
# parsed file count = 3982
# parsed file count = 3983
# parsed file count = 3984
# parsed file count = 3985
# parsed file count = 3986
# parsed file count = 3987
# parsed file count = 3988
# parsed file count = 3989
# parsed file count = 3990
# parsed file count = 3991
# parsed file count = 3992
# <class 'str'>

# %% [markdown]
# #### Run video through MTCNN
#
# We iterate through each frame, detect faces, and draw their bounding boxes on the video frames.

# %%
imgs =[]
#print('\rTracking frame: {}'.format(i + 1), end='')

# Detect faces
for count,img in enumerate(images):
    os.chdir(path)
    try:
        print(img)
        img = Image.open(img)
        boxes, _ = mtcnn.detect(img)

        # Draw faces
        frame_draw = img.copy()
        draw = ImageDraw.Draw(frame_draw)
        try:
            for box in boxes:
                draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)
                print(box)

            cropped_img = img.copy()
            cropped_img = cropped_img.crop(boxes[0])
            #d = display.display(cropped_img, display_id=True)
            os.chdir(save_path)
            cropped_img.save("img_"+"c"+str(count)+".jpeg")
            print("saved!! @ "+ "img_"+"c"+str(count)+".jpeg")


            # Add to frame list
            imgs.append(frame_draw.resize((640, 360), Image.BILINEAR))
            print('\nDone')
        except:
            print("caught!!")
    except:
        print("caught 2")
print("all done!!")
# Out:
# 14147.jpg
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 10
#       8 print(img)
#       9 img = Image.open(img)
# ---> 10 boxes, _ = mtcnn.detect(img)
#      12 # Draw faces
#      13 frame_draw = img.copy()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/facenet_pytorch/models/mtcnn.py:313, in MTCNN.detect(self, img, landmarks)
#     273 """Detect all faces in PIL image and return bounding boxes and optional facial landmarks.
#     274
#     275 This method is used by the forward method and is also useful for face detection tasks
#    (...)
#     309 >>> img_draw.save('annotated_faces.png')
#     310 """
#     312 with torch.no_grad():
# --> 313     batch_boxes, batch_points = detect_face(
#     314         img, self.min_face_size,
#     315         self.pnet, self.rnet, self.onet,
#     316         self.thresholds, self.factor,
#     317         self.device
#     318     )
#     320 boxes, probs, points = [], [], []
#     321 for box, point in zip(batch_boxes, batch_points):
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/facenet_pytorch/models/utils/detect_face.py:46, in detect_face(imgs, minsize, pnet, rnet, onet, threshold, factor, device)
#      41     imgs = torch.as_tensor(imgs.copy(), device=device)
#      45 model_dtype = next(pnet.parameters()).dtype
# ---> 46 imgs = imgs.permute(0, 3, 1, 2).type(model_dtype)
#      48 batch_size = len(imgs)
#      49 h, w = imgs.shape[2:4]
#
# RuntimeError: permute(sparse_coo): number of dimensions in the tensor input does not match the length of the desired ordering of dimensions i.e. input.dim() = 3 is not equal to len(dims) = 4

# %%
'''frames_tracked = []
for i, frame in enumerate(frames):
    print('\rTracking frame: {}'.format(i + 1), end='')
    
    # Detect faces
    boxes, _ = mtcnn.detect(frame)
    
    # Draw faces
    frame_draw = frame.copy()
    draw = ImageDraw.Draw(frame_draw)
    for box in boxes:
        draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)
    
    # Add to frame list
    frames_tracked.append(frame_draw.resize((640, 360), Image.BILINEAR))
print('\nDone')'''
# Out:
# "frames_tracked = []\nfor i, frame in enumerate(frames):\n    print('\rTracking frame: {}'.format(i + 1), end='')\n    \n    # Detect faces\n    boxes, _ = mtcnn.detect(frame)\n    \n    # Draw faces\n    frame_draw = frame.copy()\n    draw = ImageDraw.Draw(frame_draw)\n    for box in boxes:\n        draw.rectangle(box.tolist(), outline=(255, 0, 0), width=6)\n    \n    # Add to frame list\n    frames_tracked.append(frame_draw.resize((640, 360), Image.BILINEAR))\nprint('\nDone')"

# %% [markdown]
# #### Display detections

# %%
#d = display.display(imgs[0], display_id=True)
#for img in imgs:
#    display.display(img,display_id=True)

# %%
'''d = display.display(frames_tracked[0], display_id=True)
i = 1
try:
    while True:
        d.update(frames_tracked[i % len(frames_tracked)])
        i += 1
except KeyboardInterrupt:
    pass'''
# Out:
# 'd = display.display(frames_tracked[0], display_id=True)\ni = 1\ntry:\n    while True:\n        d.update(frames_tracked[i % len(frames_tracked)])\n        i += 1\nexcept KeyboardInterrupt:\n    pass'

# %% [markdown]
# #### Save tracked video

# %%
'''dim = frames_tracked[0].size
fourcc = cv2.VideoWriter_fourcc(*'FMP4')    
video_tracked = cv2.VideoWriter('video_tracked.mp4', fourcc, 25.0, dim)
for frame in frames_tracked:
    video_tracked.write(cv2.cvtColor(np.array(frame), cv2.COLOR_RGB2BGR))
video_tracked.release()'''
# Out:
# "dim = frames_tracked[0].size\nfourcc = cv2.VideoWriter_fourcc(*'FMP4')    \nvideo_tracked = cv2.VideoWriter('video_tracked.mp4', fourcc, 25.0, dim)\nfor frame in frames_tracked:\n    video_tracked.write(cv2.cvtColor(np.array(frame), cv2.COLOR_RGB2BGR))\nvideo_tracked.release()"
